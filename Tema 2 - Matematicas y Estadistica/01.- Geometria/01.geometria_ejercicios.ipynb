# %% [markdown]
# ## Ejercicios - Geometria

# %%
import numpy as np

import matplotlib
import matplotlib.pyplot as plt

import random

# %%
# Versiones

print(f"numpy=={np.__version__}")
print(f"matplotlib=={matplotlib.__version__}")
# Out:
# numpy==1.26.4
# matplotlib==3.9.2

# %% [markdown]
# ### Ejercicio 1:
# - Muestra una recta a partir los siguientes puntos:
#     - $P1(-2, -2)$
#     - $P2(2, 5)$

# %%
P1 = (-2, -2)
P2 = (2, 5)

# Mostramos punto 1
plt.plot(P1[0], P1[1], marker = "o", color = "blue")

# Mostramos punto 2
plt.plot(P2[0], P2[1], marker = "o", color = "green")

# Mostramnos la recta
plt.plot([P1[0], P2[0]], [P1[1], P2[1]], color = "red")

# Mostramos el Eje X
# plt.axhline() - Funcion para dibujar una linea horizontal
# 0 - Es el primer argumento e indica la posicion donde se hubicara el eje X en el eje Y 
# Color - Indica el color del la linea
plt.axhline(0, color = "black") 

# Mostramos el Eje Y
# plt.axvline() - Funcion para dibujar una linea vertical
plt.axvline(0, color = "black")

# Mostramos la cuadricula
plt.grid()

# Mostramos el grafico
plt.show()

# %% [markdown]
# ### Ejercicio 2:
# - Usando la ecuación de la recta, encuentra la recta de los dos puntos del ejercicio anterior.
#
# $$
# y = \frac{(y_2 - y_1)(x - x_1)}{x_2 - x_1} + y_1
# $$
#
# - Usando _**x = np.linspace(-10, 10, 2)**_ grafica la recta.
# - Grafica también los dos puntos.

# %%
P1 = (-2, -2)
P2 = (2, 5)
x = np.linspace(-10, 10, 2) # Genera 2 valores en el Eje X igualmete espaciados en el rango que indiquemos, en este caso desde -10 a 10 
# La recta se crea en funcion de estos valores
# Esto se hace para extender la gráfica de la recta entre esos valores.

y = ( ( (P2[1] - P1[1]) * (x-P1[0]) ) / (P2[0] - P1[0] ) ) + P1[1] # Es la formula de arriba, la formula de la recta

print(f"x: {x}") # Mostramos los puntos de la recta 
print(f"y: {y}")

# Punto 1
plt.plot(P1[0], P1[1], marker = "o", color = "blue") 

# Punto 2
plt.plot(P2[0], P2[1], marker = "o", color = "red") 

# Recta
plt.plot(x, y)

# Eje X e Y
plt.axhline(0, color = "black")
plt.axvline(0, color = "black")

# Mostrar el grid o cuadricula
plt.grid()
plt.show()
# Out:
# x: [-10.  10.]
# y: [-16.  19.]

# %% [markdown]
# ### Ejercicio 3:
#
# - Define una función que tome como parámetro un número entero $n$ y que genere una lista de números enteros aleatorios entre el 1 y el 10.000 usando la librería _**random**_.

# %%
import random

def list_aleatoria(numero):
    lista = []
    for i in range(numero):
        num_aleatorio = random.randint (1, 10_000)
        lista.append(num_aleatorio)
    return lista

# %%
list_aleatoria(4)
# Out:
# [3924, 7011, 4034, 8307]

# %%
# Manera simplificada
def list_aleatoria(numero):
    return [random.randint(1, 10_000) for x in range(numero)]

# %%
list_aleatoria(8)
# Out:
# [8017, 5161, 142, 8282, 8731, 513, 9352, 1786]

# %% [markdown]
# ### Ejercicio 4:
#
# - Define una función que tome como parámetro un número entero $n$ y que genere una lista de 0's y 1's de forma aleatoria usando la librería _**random**_.

# %%
def generar_numeros_0_1(n):
    lista = [] # Lista vacia donde se almacena
    opciones = [0, 1] # Lista con los valores posibles para crear los números
    for i in range(n): # Bucle que se repetira el numero de veces que pongamso cuando llamemos a la funcion (n)
        
        lista.append(random.choice(opciones)) 
        # Lista.append() Añade los numeros a la lista vacia que se llama "lista"
        # random.choice(opciones) Selecciona aleatoriamente un 0 o un 1 de la lista "opciones"
        
    return lista # Devuelve la lista donde se han ido almacenando los numeros

generar_numeros_0_1(8)
# Out:
# [0, 1, 0, 0, 1, 0, 1, 0]

# %% [markdown]
# ### Ejercicio 5:
#
# - Define una función que reciba dos listas y que calcule la _**distancia Euclideana**_.
#
# $$D(P1, P2) = \sqrt[]{\sum_{i = 0}^{n} (x_{i} - y_{i})^{2}}$$
#
# - Genera dos listas con la función del _**ejercicio 1**_ función y calcula la distancia de esas dos listas.
#
# - Genera dos listas con la función del _**ejercicio 2**_ función y calcula la distancia de esas dos listas.

# %% [markdown]
# ### Ejercicio 4:
#
# - Define una función que reciba dos listas y que calcule la _**distancia Manhattan**_.
#
# $$\text {Manhattan} = \sum_{i = 0}^{n}\left| x_{i} - y_{i} \right|$$
#
# - Genera dos listas con la función del _**ejercicio 1**_ función y calcula la distancia de esas dos listas.
#
# - Genera dos listas con la función del _**ejercicio 2**_ función y calcula la distancia de esas dos listas.

# %% [markdown]
# ### Ejercicio 5:
#
# - Define una función que reciba dos listas y que calcule la _**distancia Chebyshev**_.
#
# $$\text{Chebysev} = max(\left| x_{1} - x_{0} \right|, \left| y_{1} - y_{0} \right|, ..., \left| k_{1} - k_{0} \right|)$$
#
# - Genera dos listas con la función del _**ejercicio 1**_ función y calcula la distancia de esas dos listas.
#
# - Genera dos listas con la función del _**ejercicio 2**_ función y calcula la distancia de esas dos listas.

# %% [markdown]
# ### Ejercicio 6:
#
# - Define una función que reciba dos listas y un valor $p$ y que calcule la _**distancia Minkowski**_.
#
# $$
# \text{Minkowski} = \left(\sum_{i=1}^{n}\left|x_i - y_i\right|^{p}\right)^{\frac{1}{p}}
# $$
#
# - Genera dos listas con la función del _**ejercicio 1**_ función y calcula la distancia de esas dos listas.
#
# - Genera dos listas con la función del _**ejercicio 2**_ función y calcula la distancia de esas dos listas.

# %%
##############################################################################################################################
