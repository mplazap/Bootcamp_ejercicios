# %% [markdown]
# Crea una clase usuario
# lista de objetos de la clase usuario
# Con la estructura del menu while crear un menu while de opciones, donde las opciones sean:
#     Imprimir los usuarios de la lista
#
#     Imprimir un usuario por su ID (Bucle que busque por id) Con imput preguntamos que usuario quiere ver y que lo imprima
#
#     Crear un objeto usuario, preguntar datos con la funcion imput() Nombre (str), mail (str), edad (int), estudiante (bool) opcinal fecha cumpleaños con date
#
#     Actualizar un usuario existente (modificar losd datos de un usuario por el que preguntamos)
#
#     Borrar un usuario por su email
#
#     Borrar todos los usuarios
#
#     Salir
#
# Extra opcional guardar los usuarios en un csv

# %%
# EJEMPLO 

class Product:
    def __init__(self, title):
        self.title = title
        

# Para sacar los datos e imprimirlos podemos usar el metodo __str__
    def __str__(self):
        return f"Product: title {self.title}, price {self.price}"

# %%
# Ejemplo de como mostrar 1 producto
"""
case 2:
            title = input("Introduce el título del producto")
            
            # Bucle for que itere los productos y compruebe el titulo
            for producto in lista_productos:
                
                if title == producto.title:
                    print(f"Producto: {producto.title}")
                    print(f"Precio: {producto.price}€")
                    print(f"IVA: {producto.calcular_iva()}€")
                    print(f"Precio total con IVA: {producto.price + producto.calcular_iva()}€")
                    print("-" * 30
"""

# %% [markdown]
# * Crear una clase Usuario
# * lista de objetos de la clase Usuario
# * Crear un menú de opciones donde las opciones sean:
#
#   * Opción 1: Imprimir todos los usuarios de la lista
#
#   * Opción 2: Imprimir un usuario por su email: Ejemplo, con input preguntamos qué usuario quiere ver, y ese cuyo id coincida lo imprimimos.
#
#   * Opción 3: Crear un nuevo objeto usuario, se le puede pedir los datos con input():
#     * nombre (str)
#     * email (str)
#     * edad (int)
#     * estudiante (bool)
#     * Opcional: fecha cumpleaños con date
#
#   * Opción 4: Actualizar un usuario que ya exista
#
#   * Opción 5: borrar un usuario por su email
#
#   * Opción 6: borrar todos los usuarios
#
#   * Opción 7: Salir
#
# Extra opcional: guardar los usuarios en un csv según se crean en la lista.

# %%
class Usuarios:
    nombre = ""
    apellido = ""
    dni = ""
    email = ""
    id = ""
    
    def __init__ (self, nombre, apellido, dni, email):
        self.nombre = nombre
        self.apellido = apellido
        self.dni = dni
        self.email = email
        
        import random   
        self.id = random.randint(0, 999) # Asi es atributo de instancia     
        # Usuarios.id = random.randint(0, 999) Asi es atributo de clase
    def __str__ (self):
        return f"Usuarios:\n Nombre = {self.nombre}\n Apellido = {self.apellido}\n DNI ={self.dni}\n Email = {self.email}\n ID = {self.id}\n"

usuario1 = Usuarios (nombre = "Pepe", apellido = "Martinez", dni = "8907654Y", email = "usuario1@gmail.com")
usuario2 = Usuarios (nombre = "Luis", apellido = "Gonzalez", dni = "6923837Q", email = "usuario2@gmail.com")
usuario3 = Usuarios (nombre = "Juan", apellido = "Lopez", dni = "2840281P", email = "usuario3@gmail.com")

Usuarios = [usuario1, usuario2, usuario3]
  
menu = """
    Bienvenido, elije una de las opciones:\n
        1.- Ver todos los usuarios
        2.- Buscar usuario por Email
        3.- Crear nuevo usuario
        4.- Actualizar usuario existente
        5.- Borrar usuario
        6.- Borrar todos los usuario
        7.- Salir
        """
   
while True:
    opcion = int(input(menu))
    match opcion:
        case 1:
            for usuario in Usuarios:
                print(usuario)
            
            
    
#usuario = Usuarios (nombre = "Pepe", apellido = "Martinez", dni = "8907654Y", email = "usuario@gmail.com")
#print(usuario)
