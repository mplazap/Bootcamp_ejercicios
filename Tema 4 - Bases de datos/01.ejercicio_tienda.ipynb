# %% [markdown]
# ## MySQL - Ejercicio 01
#
# 01. Definir y crear la siguiente base de datos:
# - El nombre de la base de datos es **tienda**.
# - El orden para crear las tablas es el siguiente:
#     - **Marca**
#     - **Categoria**
#     - **Modelo**
#     - **Cliente**
#     - **Producto**
#     - **Características**
#     - **Venta**
#     - **Devolución**
#     - **Historial de Precios**
#
# ![tienda_modelo_entidad_relaci%C3%B3n.png](attachment:tienda_modelo_entidad_relaci%C3%B3n.png)
#
# Puedes usar las funciones definidas en clase para crear la base de datos en **MySQL**.

# %% [markdown]
# 02. Usando los archivos **.pkl** de la carpeta _**"tienda"**_ popular las tablas de la base de datos en el mismo orden en las que fueron creadas.
#
# - El orden para popular las tablas es el siguiente:
#     - **Marca**
#     - **Categoria**
#     - **Modelo**
#     - **Cliente**
#     - **Producto**
#     - **Características**
#     - **Venta**
#     - **Devolución**
#     - **Historial de Precios**
#
# Puedes usar las funciones definidas en clase para crear la base de datos en **MySQL**.

# %%
################################################################################################################################
