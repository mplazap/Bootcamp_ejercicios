# %% [markdown]
# ## Conceptos Básicos de Python: Tipos de Datos, Operadores y Variables
#
# Este documento explica los conceptos fundamentales en Python, incluyendo **tipos de datos, operadores aritméticos, variables, booleanos, operadores de comparación y operadores lógicos**, con ejemplos.
#
# ### **1️⃣ Tipos de Datos en Python**
# En Python, existen varios **tipos de datos** que se utilizan para representar valores.
#
# | Tipo | Descripción | Ejemplo |
# |------|------------|---------|
# | `int` | Números enteros | `10`, `-5` |
# | `float` | Números decimales | `3.14`, `-2.5` |
# | `str` | Cadenas de texto | `"Hola"`, `'Python'` |
# | `bool` | Valores booleanos | `True`, `False` |
# | `list` | Lista de elementos | `[1, 2, 3]`, `["a", "b", "c"]` |
# | `tuple` | Tupla (lista inmutable) | `(4, 5, 6)` |
# | `dict` | Diccionario (pares clave-valor) | `{"nombre": "Juan", "edad": 30}` |
# | `set` | Conjunto (colección sin duplicados) | `{1, 2, 3, 3}` |
#
# ```python
# # Ejemplo de tipos de datos
# num = 10         # int
# pi = 3.14        # float
# texto = "Python" # str
# es_mayor = True  # bool
# lista = [1, 2, 3] # list
# tupla = (4, 5, 6) # tuple
# dicc = {"nombre": "Juan", "edad": 30} # dict
# conjunto = {1, 2, 3, 3} # set
# ```
#
# ### **2️⃣ Variables en Python**
# Las variables almacenan valores y se definen sin necesidad de declarar el tipo.
#
# ```python
# nombre = "Carlos"   # str
# edad = 25           # int
# altura = 1.75       # float
# es_estudiante = True # bool
#
# print(nombre, edad, altura, es_estudiante)
# # ✅ Salida: Carlos 25 1.75 True
# ```
#
# 📌 **Reglas para los nombres de variables:**
# ✔ Deben comenzar con una letra o `_`
# ✔ No pueden contener espacios
# ✔ Son **sensibles a mayúsculas y minúsculas** (`Edad` ≠ `edad`)
#
#
# ### **3️⃣ Operadores Aritméticos**
# Los operadores aritméticos se usan para realizar operaciones matemáticas.
#
# | Operador | Descripción | Ejemplo |
# |----------|------------|---------|
# | `+` | Suma | `5 + 3` → `8` |
# | `-` | Resta | `10 - 4` → `6` |
# | `*` | Multiplicación | `6 * 3` → `18` |
# | `/` | División (float) | `10 / 2` → `5.0` |
# | `//` | División entera | `10 // 3` → `3` |
# | `%` | Módulo (resto) | `10 % 3` → `1` |
# | `**` | Exponente | `2 ** 3` → `8` |
#
# ```python
# a = 10
# b = 3
#
# print(a + b)  # ✅ 13
# print(a - b)  # ✅ 7
# print(a * b)  # ✅ 30
# print(a / b)  # ✅ 3.3333...
# print(a // b) # ✅ 3
# print(a % b)  # ✅ 1
# print(a ** b) # ✅ 1000
# ```
#
#
# ### **4️⃣ Booleanos en Python**
# Los valores **`True`** y **`False`** son de tipo `bool` y se usan en condiciones.
#
# ```python
# es_adulto = True
# menor_edad = False
# ```
#
# Los booleanos también se pueden obtener con operadores de comparación:
# ```python
# print(10 > 5)   # ✅ True
# print(3 == 7)   # ✅ False
# ```
#
#
# ### **5️⃣ Operadores de Comparación**
# Se usan para comparar valores y devuelven un booleano (`True` o `False`).
#
# | Operador | Descripción | Ejemplo (`a = 10, b = 3`) | Resultado |
# |----------|------------|------------------|----------|
# | `==` | Igual a | `a == b` | `False` |
# | `!=` | Diferente de | `a != b` | `True` |
# | `>` | Mayor que | `a > b` | `True` |
# | `<` | Menor que | `a < b` | `False` |
# | `>=` | Mayor o igual que | `a >= b` | `True` |
# | `<=` | Menor o igual que | `a <= b` | `False` |
#
# ```python
# a = 10
# b = 3
#
# print(a == b)  # ✅ False
# print(a != b)  # ✅ True
# print(a > b)   # ✅ True
# print(a < b)   # ✅ False
# print(a >= b)  # ✅ True
# print(a <= b)  # ✅ False
# ```
#
#
# ### **6️⃣ Operadores Lógicos**
# Se usan para combinar expresiones booleanas.
#
# | Operador | Descripción | Ejemplo (`a = 10, b = 3`) | Resultado |
# |----------|------------|------------------|----------|
# | `and` | True si ambas condiciones son verdaderas | `a > 5 and b < 5` | `True` |
# | `or` | True si al menos una condición es verdadera | `a < 5 or b < 5` | `True` |
# | `not` | Invierte el valor booleano | `not(a > 5)` | `False` |
#
# ```python
# a = 10
# b = 3
#
# print(a > 5 and b < 5)  # ✅ True
# print(a < 5 or b < 5)   # ✅ True
# print(not (a > 5))      # ✅ False
# ```
#
#
# ### **🚀 Conclusión**
# ✔ Python tiene varios **tipos de datos** (`int`, `float`, `str`, `bool`, `list`, etc.).
# ✔ Las **variables** almacenan valores sin necesidad de especificar un tipo.
# ✔ Los **operadores aritméticos** permiten realizar cálculos matemáticos.
# ✔ Los **operadores de comparación** devuelven valores booleanos (`True` o `False`).
# ✔ Los **operadores lógicos** permiten combinar expresiones booleanas.

# %% [markdown]
# # Métodos de Strings en Python
#
# Los strings en Python tienen muchos métodos integrados que permiten manipular y procesar texto de manera eficiente.
# A continuación, se presenta un listado de los métodos más comunes con una breve descripción y un ejemplo de uso.
#
# ### 1️⃣ `capitalize()`
# Convierte la primera letra en mayúscula y el resto en minúscula.
#
# ```python
# texto = "hola mundo"
# print(texto.capitalize())  # ✅ 'Hola mundo'
# ```
#
# ### 2️⃣ `casefold()`
# Convierte el texto a minúsculas, similar a `lower()`, pero más agresivo en términos de normalización.
#
# ```python
# texto = "MAYÚSCULAS"
# print(texto.casefold())  # ✅ 'mayúsculas'
# ```
#
# ---
#
# ### 3️⃣ `center(width, fillchar)`
# Centra el texto dentro de un ancho específico, rellenando con un carácter opcional.
#
# ```python
# texto = "Python"
# print(texto.center(10, "-"))  # ✅ '--Python--'
# ```
#
# ### 4️⃣ `count(sub, start, end)`
# Cuenta cuántas veces aparece una subcadena en el string.
#
# ```python
# texto = "banana banana banana"
# print(texto.count("banana"))  # ✅ 3
# ```
#
# ### 5️⃣ `endswith(suffix, start, end)`
# Devuelve `True` si el string termina con el sufijo especificado.
#
# ```python
# texto = "hola mundo.py"
# print(texto.endswith(".py"))  # ✅ True
# ```
#
# ### 6️⃣ `startswith(prefix, start, end)`
# Devuelve `True` si el string comienza con el prefijo especificado.
#
# ```python
# texto = "Python es genial"
# print(texto.startswith("Python"))  # ✅ True
# ```
#
# ### 7️⃣ `find(sub, start, end)`
# Devuelve el índice de la primera aparición de la subcadena. Retorna `-1` si no se encuentra.
#
# ```python
# texto = "Hola mundo"
# print(texto.find("mundo"))  # ✅ 5
# print(texto.find("Python")) # ✅ -1 (no encontrado)
# ```
#
# ### 8️⃣ `index(sub, start, end)`
# Similar a `find()`, pero lanza un error `ValueError` si no se encuentra la subcadena.
#
# ```python
# texto = "Hola mundo"
# print(texto.index("mundo"))  # ✅ 5
# ```
#
# ### 9️⃣ `isalpha()`
# Devuelve `True` si todos los caracteres son letras.
#
# ```python
# texto = "Python"
# print(texto.isalpha())  # ✅ True
# ```
#
# ### 🔟 `isdigit()`
# Devuelve `True` si todos los caracteres son dígitos.
#
# ```python
# texto = "12345"
# print(texto.isdigit())  # ✅ True
# ```
#
# ### 1️⃣1️⃣ `islower()`
# Devuelve `True` si todos los caracteres están en minúscula.
#
# ```python
# texto = "python"
# print(texto.islower())  # ✅ True
# ```
#
# ### 1️⃣2️⃣ `isupper()`
# Devuelve `True` si todos los caracteres están en mayúscula.
#
# ```python
# texto = "PYTHON"
# print(texto.isupper())  # ✅ True
# ```
#
# ### 1️⃣3️⃣ `isspace()`
# Devuelve `True` si el string contiene solo espacios en blanco.
#
# ```python
# texto = "   "
# print(texto.isspace())  # ✅ True
# ```
#
# ### 1️⃣4️⃣ `join(iterable)`
# Une una lista de strings con el string como separador.
#
# ```python
# palabras = ["Hola", "mundo", "Python"]
# print(" ".join(palabras))  # ✅ 'Hola mundo Python'
# ```
#
# ### 1️⃣5️⃣ `lower()`
# Convierte el string a minúsculas.
#
# ```python
# texto = "MAYÚSCULAS"
# print(texto.lower())  # ✅ 'mayúsculas'
# ```
#
# ### 1️⃣6️⃣ `upper()`
# Convierte el string a mayúsculas.
#
# ```python
# texto = "minúsculas"
# print(texto.upper())  # ✅ 'MINÚSCULAS'
# ```
#
# ### 1️⃣7️⃣ `replace(old, new, count)`
# Reemplaza una subcadena por otra.
#
# ```python
# texto = "Hola mundo"
# print(texto.replace("mundo", "Python"))  # ✅ 'Hola Python'
# ```
#
# ### 1️⃣8️⃣ `split(sep, maxsplit)`
# Divide el string en una lista usando un separador.
#
# ```python
# texto = "manzana,pera,uva"
# print(texto.split(","))  # ✅ ['manzana', 'pera', 'uva']
# ```
#
# ### 1️⃣9️⃣ `strip(chars)`
# Elimina espacios en blanco o caracteres específicos al inicio y al final.
#
# ```python
# texto = "  hola  "
# print(texto.strip())  # ✅ 'hola'
# ```
#
# ### 2️⃣0️⃣ `swapcase()`
# Invierte las mayúsculas y minúsculas en un string.
#
# ```python
# texto = "Hola Mundo"
# print(texto.swapcase())  # ✅ 'hOLA mUNDO'
# ```
#
# ### 2️⃣1️⃣ `title()`
# Convierte la primera letra de cada palabra en mayúscula.
#
# ```python
# texto = "hola mundo"
# print(texto.title())  # ✅ 'Hola Mundo'
# ```
#
# ### 2️⃣2️⃣ `zfill(width)`
# Rellena el string con ceros a la izquierda hasta alcanzar el ancho especificado.
#
# ```python
# numero = "42"
# print(numero.zfill(5))  # ✅ '00042'
# ```

# %% [markdown]
# ##  Bucles en Python: `for` y `while`
#
# Los bucles en Python permiten ejecutar un bloque de código varias veces.
# Existen dos tipos principales de bucles en Python: **`for`** y **`while`**.
#
#
# ### **1️⃣ Bucle `for`**
# Se usa para iterar sobre una secuencia (listas, tuplas, strings, rangos, etc.).
#
# ### **📌 Sintaxis**
# ```python
# for variable in secuencia:
#     # Código a ejecutar en cada iteración
# ```
#
# ### **🔹 Ejemplo: Iterar sobre una lista**
# ```python
# frutas = ["manzana", "pera", "uva"]
# for fruta in frutas:
#     print(fruta)
# ```
# 📌 **Salida:**
# ```
# manzana
# pera
# uva
# ```
#
# ---
#
# ### **🔹 Usando `range()` en un `for`**
# ```python
# for i in range(5):
#     print(i)
# ```
# 📌 **Salida:** `0, 1, 2, 3, 4`
# 🔹 `range(5)` genera los números del **0 al 4**.
#
# ---
#
# ### **🔹 Iterar sobre un string**
# ```python
# palabra = "Python"
# for letra in palabra:
#     print(letra)
# ```
# 📌 **Salida:**
# ```
# P
# y
# t
# h
# o
# n
# ```
#
# ---
#
# ### **🔹 `for` con `enumerate()`**
# La función `enumerate()` permite obtener el índice y el valor en un bucle.
#
# ```python
# frutas = ["manzana", "pera", "uva"]
# for indice, fruta in enumerate(frutas):
#     print(f"Índice {indice}: {fruta}")
# ```
# 📌 **Salida:**
# ```
# Índice 0: manzana
# Índice 1: pera
# Índice 2: uva
# ```
#
#
# ### **2️⃣ Bucle `while`**
# El bucle `while` ejecuta un bloque de código **mientras una condición sea `True`**.
#
# ### **📌 Sintaxis**
# ```python
# while condicion:
#     # Código que se ejecuta mientras la condición sea True
# ```
#
# ---
#
# ### **🔹 Ejemplo básico con `while`**
# ```python
# contador = 0
# while contador < 5:
#     print(contador)
#     contador += 1
# ```
# 📌 **Salida:** `0, 1, 2, 3, 4`
# 🔹 **El bucle se detiene cuando `contador` llega a 5**.
#
# ---
#
# ### **🔹 `while` con entrada del usuario**
# ```python
# respuesta = ""
# while respuesta != "salir":
#     respuesta = input("Escribe algo (o 'salir' para terminar): ")
#     print(f"Escribiste: {respuesta}")
# ```
# 📌 **Este bucle continúa hasta que el usuario escriba "salir".**
#
#
# ### **3️⃣ Control de Bucles con `break` y `continue`**
#
# ### **🔹 `break`: Salir del bucle**
# ```python
# for numero in range(10):
#     if numero == 5:
#         break  # Sale del bucle cuando numero es 5
#     print(numero)
# ```
# 📌 **Salida:** `0, 1, 2, 3, 4`
# 🔹 **El bucle se detiene en `5`, no llega a imprimir `5` ni los siguientes números.**
#
# ---
#
# ### **🔹 `continue`: Saltar una iteración**
# ```python
# for numero in range(5):
#     if numero == 2:
#         continue  # Salta la iteración cuando numero es 2
#     print(numero)
# ```
# 📌 **Salida:** `0, 1, 3, 4`
# 🔹 **El `2` no se imprime porque se salta esa iteración.**
#
# ---
#
# ## **4️⃣ `else` en bucles**
# Tanto `for` como `while` pueden tener una cláusula `else`, que se ejecuta cuando el bucle termina normalmente (sin `break`).
#
# ### **🔹 `else` en `for`**
# ```python
# for i in range(3):
#     print(i)
# else:
#     print("El bucle terminó correctamente")
# ```
# 📌 **Salida:**
# ```
# 0
# 1
# 2
# El bucle terminó correctamente
# ```
#
# ### **🔹 `else` en `while`**
# ```python
# contador = 0
# while contador < 3:
#     print(contador)
#     contador += 1
# else:
#     print("Bucle terminado")
# ```
# 📌 **Salida:**
# ```
# 0
# 1
# 2
# Bucle terminado
# ```
#
# ---
#
# ## **🚀 Conclusión**
# ✔ **`for`** se usa para recorrer secuencias como listas, strings y rangos.
# ✔ **`while`** se ejecuta mientras una condición sea `True`.
# ✔ **`break`** interrumpe un bucle antes de que termine.
# ✔ **`continue`** salta una iteración del bucle.
# ✔ **`else`** en un bucle se ejecuta si el bucle finaliza sin interrupciones.

# %% [markdown]
# ##  Condicionales, Casting y `input()` en Python
#
# Este documento explica el uso de **condicionales (`if`, `elif`, `else`), condicionales anidados, casting (conversión de tipos) y la función `input()`** en Python, con ejemplos.
#
#
# ### **1️⃣ Condicionales en Python (`if`, `elif`, `else`)**
# Los condicionales permiten ejecutar código solo si se cumple una condición.
#
# ### **📌 Sintaxis**
# ```python
# if condicion:
#     # Código que se ejecuta si la condición es True
# elif otra_condicion:
#     # Código que se ejecuta si la primera condición es False, pero esta es True
# else:
#     # Código que se ejecuta si ninguna condición anterior es True
# ```
#
# ---
#
# ### **🔹 Ejemplo de `if`, `elif` y `else`**
# ```python
# edad = 18
#
# if edad < 18:
#     print("Eres menor de edad")
# elif edad == 18:
#     print("Tienes exactamente 18 años")
# else:
#     print("Eres mayor de edad")
# ```
# 📌 **Salida:** `"Tienes exactamente 18 años"`
# 🔹 **La condición `elif` se cumple porque `edad == 18`**.
#
#
# ### **2️⃣ Condicionales Anidados**
# Los condicionales pueden anidarse dentro de otros para evaluar múltiples condiciones.
#
# ```python
# edad = 25
# tiene_identificacion = True
#
# if edad >= 18:
#     if tiene_identificacion:
#         print("Puedes entrar al evento")
#     else:
#         print("No puedes entrar sin identificación")
# else:
#     print("No puedes entrar porque eres menor de edad")
# ```
# 📌 **Salida:** `"Puedes entrar al evento"`
# 🔹 **El `if` anidado verifica si el usuario tiene identificación**.
#
#
# ### **3️⃣ Casting en Python (Conversión de Tipos)**
# El **casting** permite convertir datos de un tipo a otro.
#
# ### **📌 Tipos de Casting en Python**
# | Función | Conversión | Ejemplo |
# |---------|------------|----------|
# | `int()` | Convierte a entero | `int("10")` → `10` |
# | `float()` | Convierte a decimal | `float("3.14")` → `3.14` |
# | `str()` | Convierte a string | `str(100)` → `"100"` |
# | `bool()` | Convierte a booleano | `bool(1)` → `True` |
#
# ---
#
# ### **🔹 Ejemplo de conversión de tipos**
# ```python
# num_texto = "42"
# num_entero = int(num_texto)  # Convierte string a entero
# num_decimal = float(num_texto)  # Convierte string a float
#
# print(num_entero + 10)  # ✅ 52
# print(num_decimal + 0.5)  # ✅ 42.5
# ```
#
# ---
#
# ### **🔹 Casting en `input()`**
# ```python
# edad = int(input("Ingresa tu edad: "))
# print(f"El próximo año tendrás {edad + 1} años.")
# ```
# 📌 **Si el usuario ingresa `"20"`, `input()` devuelve un string, pero `int()` lo convierte a número.**
# 📌 **Salida:** `"El próximo año tendrás 21 años."`
#
#
# ### **4️⃣ `input()` en Python (Entrada del Usuario)**
# La función **`input()`** permite al usuario ingresar datos en tiempo de ejecución.
#
# ### **📌 Ejemplo básico**
# ```python
# nombre = input("¿Cuál es tu nombre? ")
# print("Hola, " + nombre + "!")
# ```
# 📌 **El usuario ingresa su nombre y se muestra un saludo personalizado.**
#
# ---
#
# ### **🔹 `input()` con casting**
# ```python
# edad = int(input("¿Cuántos años tienes? "))
# print(f"En 5 años tendrás {edad + 5} años.")
# ```
# 📌 **Convierte la entrada del usuario a `int`, permitiendo hacer cálculos.**
#
# ---
#
# ### **🔹 `input()` en una condición**
# ```python
# respuesta = input("¿Te gusta Python? (sí/no): ").lower()
#
# if respuesta == "sí":
#     print("¡Genial! Python es muy útil.")
# else:
#     print("Deberías darle otra oportunidad.")
# ```
# 📌 **Usamos `.lower()` para evitar problemas con mayúsculas y minúsculas.**
#
# ---
#
# ## **🚀 Conclusión**
# ✔ **Los condicionales (`if`, `elif`, `else`) permiten tomar decisiones en el código.**
# ✔ **Los condicionales anidados permiten evaluar múltiples condiciones dentro de otra.**
# ✔ **El casting (`int()`, `float()`, `str()`, `bool()`) convierte datos de un tipo a otro.**
# ✔ **`input()` permite interactuar con el usuario, y se puede combinar con casting.**

# %% [markdown]
# # Sets, Diccionarios y Diccionarios Anidados en Python
#
# Este documento explica cómo trabajar con **sets (conjuntos), diccionarios y diccionarios anidados** en Python, con ejemplos prácticos.
#
#
# ### **1️⃣ Sets (Conjuntos) en Python**
# Un **set** es una colección **desordenada** de elementos **únicos** (no permite duplicados).
#
# ### **📌 Crear un set**
# ```python
# numeros = {1, 2, 3, 4, 5}
# print(numeros)  # ✅ {1, 2, 3, 4, 5}
# ```
#
# ---
#
# ### **🔹 Propiedades de un set**
# ✔ No permite elementos duplicados.
# ✔ No tiene un orden específico.
# ✔ Se pueden agregar o eliminar elementos.
#
# ```python
# # No permite duplicados
# numeros = {1, 2, 2, 3, 4}
# print(numeros)  # ✅ {1, 2, 3, 4}
# ```
#
# ---
#
# ### **🔹 Métodos útiles en sets**
# | Método | Descripción | Ejemplo |
# |--------|------------|---------|
# | `add()` | Agrega un elemento al set | `mi_set.add(6)` |
# | `remove()` | Elimina un elemento (error si no existe) | `mi_set.remove(3)` |
# | `discard()` | Elimina un elemento sin error si no existe | `mi_set.discard(3)` |
# | `pop()` | Elimina un elemento aleatorio | `mi_set.pop()` |
# | `clear()` | Vacía el set | `mi_set.clear()` |
# | `union()` | Une dos sets | `set1.union(set2)` |
# | `intersection()` | Elementos comunes en dos sets | `set1.intersection(set2)` |
# | `difference()` | Elementos únicos del primer set | `set1.difference(set2)` |
#
# ```python
# mi_set = {1, 2, 3}
# mi_set.add(4)  # ✅ {1, 2, 3, 4}
# mi_set.remove(2)  # ✅ {1, 3, 4}
# otro_set = {3, 4, 5, 6}
# print(mi_set.intersection(otro_set))  # ✅ {3, 4}
# ```
#
#
# ### **2️⃣ Diccionarios en Python**
# Un **diccionario** es una colección de **pares clave-valor**, donde cada clave es única.
#
# ---
#
# ### **📌 Crear un diccionario**
# ```python
# persona = {
#     "nombre": "Carlos",
#     "edad": 30,
#     "ciudad": "Madrid"
# }
# print(persona)  # ✅ {'nombre': 'Carlos', 'edad': 30, 'ciudad': 'Madrid'}
# ```
#
# ---
#
# ### **🔹 Acceder a valores**
# ```python
# print(persona["nombre"])  # ✅ 'Carlos'
# print(persona.get("edad"))  # ✅ 30
# ```
# 📌 **Diferencia entre `[]` y `.get()`**:
# - `persona["clave"]` → Da error si la clave no existe.
# - `persona.get("clave")` → Devuelve `None` si no existe.
#
# ---
#
# ### **🔹 Agregar o modificar elementos**
# ```python
# persona["profesion"] = "Ingeniero"  # Agregar nueva clave
# persona["edad"] = 31  # Modificar edad
# print(persona)
# ```
#
# ---
#
# ### **🔹 Eliminar elementos**
# ```python
# del persona["ciudad"]
# persona.pop("edad")
# print(persona)  # ✅ {'nombre': 'Carlos', 'profesion': 'Ingeniero'}
# ```
#
# ---
#
# ### **🔹 Métodos útiles en diccionarios**
# | Método | Descripción | Ejemplo |
# |--------|------------|---------|
# | `keys()` | Devuelve las claves del diccionario | `persona.keys()` |
# | `values()` | Devuelve los valores | `persona.values()` |
# | `items()` | Devuelve pares clave-valor | `persona.items()` |
# | `pop()` | Elimina una clave y devuelve su valor | `persona.pop("edad")` |
# | `clear()` | Vacía el diccionario | `persona.clear()` |
#
# ```python
# print(persona.keys())  # ✅ dict_keys(['nombre', 'profesion'])
# print(persona.values())  # ✅ dict_values(['Carlos', 'Ingeniero'])
# print(persona.items())  # ✅ dict_items([('nombre', 'Carlos'), ('profesion', 'Ingeniero')])
# ```
#
#
# ### **3️⃣ Diccionarios Anidados**
# Un **diccionario anidado** es un diccionario que contiene otros diccionarios como valores.
#
# ---
#
# ### **📌 Crear un diccionario anidado**
# ```python
# empresa = {
#     "empleado1": {"nombre": "Ana", "edad": 28, "cargo": "Desarrolladora"},
#     "empleado2": {"nombre": "Luis", "edad": 35, "cargo": "Gerente"}
# }
# print(empresa["empleado1"]["nombre"])  # ✅ 'Ana'
# ```
#
# ---
#
# ### **🔹 Agregar nuevos empleados**
# ```python
# empresa["empleado3"] = {"nombre": "Sofía", "edad": 25, "cargo": "Diseñadora"}
# print(empresa)
# ```
#
# ---
#
# ### **🔹 Recorrer un diccionario anidado**
# ```python
# for clave, datos in empresa.items():
#     print(f"{clave}: {datos['nombre']} - {datos['cargo']}")
# ```
# 📌 **Salida:**
# ```
# empleado1: Ana - Desarrolladora
# empleado2: Luis - Gerente
# empleado3: Sofía - Diseñadora
# ```
#
# ---
#
# ## **🚀 Conclusión**
# ✔ **Los sets** almacenan elementos únicos sin orden específico.
# ✔ **Los diccionarios** almacenan pares clave-valor para organizar datos.
# ✔ **Los diccionarios anidados** permiten estructurar información compleja.
